# %% [markdown]
# ### Data Mining Project - Phase 3 - Ehsan Espandar - 99442011

# %%
import pandas as pd

# %%
data_packet = pd.read_csv('housing.csv')

# %%
from sklearn.model_selection import train_test_split

X = data_packet.drop('median_house_value', axis=1) 
y = data_packet['median_house_value'] 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2021)

print(len(X_train),len(y_train))
print(len(X_test),len(y_test))
# Out:
# 16512 16512
# 4128 4128

# %% [markdown]
# # Phase 3

# %% [markdown]
# ## Question 1

# %%
import copy
import pandas as pd

# Assuming X_train and y_train are your feature and target DataFrames respectively
X_train_copy = copy.copy(X_train)
y_train_copy = copy.copy(y_train)

# Concatenate X_train and y_train along columns axis
data = pd.concat([X_train_copy, y_train_copy], axis=1)


print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2782     -114.66     32.74                17.0       1388.0           386.0
# 8513     -118.31     33.89                35.0       2144.0           423.0
# 2163     -119.82     36.77                41.0       1441.0           274.0
# 5232     -118.24     33.94                42.0        380.0           106.0
# 9766     -121.66     36.37                 9.0       1580.0           287.0
# ...          ...       ...                 ...          ...             ...
# 16347    -121.35     38.02                16.0       1665.0           311.0
# 20318    -119.15     34.20                25.0       3445.0           898.0
# 2669     -115.51     33.24                32.0       1995.0           523.0
# 17536    -121.88     37.35                49.0       1728.0           350.0
# 6201     -117.89     34.08                25.0       2115.0           489.0
#
# ...

# %% [markdown]
# ## Question 2

# %%
import matplotlib.pyplot as plt

# Assuming data is the DataFrame and 'longitude' and 'latitude' are column names
plt.figure(figsize=(10, 7))
plt.scatter(data['longitude'], data['latitude'])

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')

plt.show()

# %% [markdown]
# ## Question 3

# %%
import matplotlib.pyplot as plt

# Assuming data is the DataFrame and 'longitude' and 'latitude' are column names
plt.figure(figsize=(10, 7))
plt.scatter(data['longitude'], data['latitude'],alpha=0.2)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')

plt.show()

# %% [markdown]
# ## Question 4

# %%
import matplotlib.pyplot as plt

# Assuming data is the DataFrame and 'longitude' and 'latitude' are column names
plt.figure(figsize=(10, 7))
plt.scatter(data['longitude'], data['latitude'],alpha=0.2,s=data['population']/30, label='population')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')

plt.show()

# %% [markdown]
# ## Question 5

# %%
import matplotlib.pyplot as plt

# Assuming data is the DataFrame and 'longitude' and 'latitude' are column names
plt.figure(figsize=(10, 7))
plt.scatter(data['longitude'], data['latitude'],alpha=0.2,s=data['population']/30, label='population')

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')

plt.show()

# %% [markdown]
# ## Question 6

# %%
corr_matrix = data.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# C:\Users\Ehsan\AppData\Local\Temp\ipykernel_11100\3974275619.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
# median_house_value    1.000000
# median_income         0.685033
# total_rooms           0.133929
# housing_median_age    0.103485
# households            0.067922
# total_bedrooms        0.051630
# population           -0.023039
# longitude            -0.043964
# latitude             -0.144514
# Name: median_house_value, dtype: float64

# %% [markdown]
# "این کد به محاسبه میزان ارتباط میان عوامل مختلف در داده و 'ارزش میانگین خانه' می‌پردازد. این کار رابطه و قدرت تاثیر هر عامل را در مقابل متغیر هدف اندازه‌گیری می‌کند. اگر همبستگی به ۱ نزدیک باشد، این به این معناست که آنها تمایل دارند همزمان افزایش یابند. اگر به -۱ نزدیک باشد، یکی افزایش پیدا می‌کند در حالی که دیگری کاهش می‌یابد. اگر به صفر نزدیک باشد، ارتباط ضعیف است و یا حتی ممکن است هیچ ارتباط خطی میان عامل و متغیر هدف وجود نداشته باشد."

# %% [markdown]
# ## Question 7

# %% [markdown]
#     median_income => (Corr: 0.685033)
#     total_rooms => (Corr: 0.133929)
#     housing_median_age => (Corr: 0.103485)
#
# => These are the most correlated features to the "median_house_value"

# %%
features = ['median_income','total_rooms','housing_median_age']
print(features)
# Out:
# ['median_income', 'total_rooms', 'housing_median_age']

# %% [markdown]
# ## Question 8

# %%
import pandas.plotting as pd_plotting
import matplotlib.pyplot as plt

# فراخوانی تابع scatter_matrix برای رسم نمودارهای پراکنشی
# data: داده‌های مورد استفاده
# figsize: اندازه نمودارها
pd_plotting.scatter_matrix(data[features], figsize=(15, 10))

# نمایش نمودارها
plt.show()

# %% [markdown]
# ## Question 9

# %% [markdown]
# برای میانه درآمد کاملا واضح است که با فزایش مقدار آن به دلیل همبستگی بالا مقدار متغیر هدف که همان میانه قیمت خانه است نیز افزایش می یابد، اما این همبستگی برای تعداد اتاق ها و میانه سال های اقامت کمتر ملموس است اما می توان فهمید که وجود دارد.

# %%
data.plot(kind='scatter',x='median_income',y='median_house_value',figsize=(10,7),alpha=0.4)
data.plot(kind='scatter',x='total_rooms',y='median_house_value',figsize=(10,7),alpha=0.4)
data.plot(kind='scatter',x='housing_median_age',y='median_house_value',figsize=(10,7),alpha=0.4)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='median_house_value'>
